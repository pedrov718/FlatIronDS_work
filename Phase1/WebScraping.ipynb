# %% [markdown]
# Using Beautiful Soup to Extract Data from a webpage Guide:

# %%
#Remeber to import your desired modules firsrt 
import requests
from bs4 import BeautifulSoup
import pandas as pd
import re

# %%
#Identify the webpage you'd like to scrape
url = "https://www.the-numbers.com/box-office-records/domestic/all-movies/cumulative/released-in-2021"

#Make a Get request to fetch the raw HTML content 
html_content = requests.get(url).text

#Parse the HTML content 

soup = BeautifulSoup(html_content, "lxml")
#print(soup.prettify());

# %%
#testing out the soup object 

print(soup.title)
print(soup.title.text)
# Out:
# <title>Top 2021 Movies at the Domestic Box Office</title>
# Top 2021 Movies at the Domestic Box Office

# %%
#Retreieving all links embedded in the webpage 
#for link in soup.find_all("a"):
#    print(f"Inner Text: {link.text}")
#    print("Title: {}".format(link.get("title")))
#    print("href: {}".format(link.get("href")))

# %%
movie_table = soup.find_all("table")
movie_table.get_
#movie_table_data = movie_table.tbody.find_all("tr")
# Out:
# [<table class="pintable">
#  <tr>
#  <td class="previous"><a href="/box-office-records/domestic/all-movies/cumulative/released-in-2020">Top 2020 Domestic</a></td>
#  <td class="index"></td>
#  <td class="next"><a href="/box-office-records/domestic/all-movies/cumulative/released-in-2022">Top 2022 Domestic</a></td>
#  </tr>
#  </table>,
#  <table>
#  <thead><tr>
#  <th>Rank</th>
#  <th>Movie</th>
#  <th>Distributor</th>
#  <th>Domestic<br/>Box<br/>Office</th>
#  <th>Opening<br/>Weekend<br/>Box Office</th>
#  <th>Max<br/>Theater<br/>Count</th>
#  </tr>
#  </thead>
#  <tbody>
#  <tr>
#  <td class="data">1</td>
#  <td><b><a href="/movie/Spider-Man-No-Way-Home-(2021)#tab=summary">Spider-Man: No Way Home</a></b></td>
#  <td><a href="/market/distributor/Sony-Pictures">Sony Pict…</a></td>
#  <td align="right">$673,570,351</td>
#  <td align="right">$260,138,569</td>
#  <td align="right">4,336</td>
#  </tr>
#  <tr>
#  <td class="data">2</td>
# ...
